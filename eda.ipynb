# %%
import pandas as pd, numpy as np
import plotly.express as px
from train import load_and_prepare

df = load_and_prepare("data/SDSS_DR18_pt1.csv")
df.shape
# Out:
# C:\Users\Juan Carlos Ruelas\Documents\Anthropic\Profesional\Projects\Github\zPhoto\photo-z-regression\train.py:18: DtypeWarning: Columns (0: class) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
# (24555, 47)

# %%
px.histogram(df, x="redshift", nbins=60, title="Spectroscopic redshift distribution")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Anthropic\Profesional\Projects\Github\zPhoto\photo-z-regression\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\Documents\Anthropic\Profesional\Projects\Github\zPhoto\photo-z-regression\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
# ...

# %%
df[["u","g","r","i","z"]].describe()
# Out:
#                   u             g             r             i             z
# count  24555.000000  24555.000000  24555.000000  24555.000000  24555.000000
# mean      18.781353     17.330971     16.635553     16.260907     16.008400
# std        0.728477      0.796142      0.883379      0.915129      0.973282
# min       13.422110     12.357220     11.629170     11.051390     10.616260
# 25%       18.458915     16.959085     16.168250     15.757080     15.439800
# 50%       18.984830     17.486790     16.740450     16.351270     16.080830
# 75%       19.314925     17.894885     17.286790     16.932675     16.720180
# max       19.599950     19.888470     29.744050     25.086790     28.234510

# %%
px.scatter(df.sample(5000), x="g_r", y="redshift", opacity=0.3,title="g-r color vs redshift")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Anthropic\Profesional\Projects\Github\zPhoto\photo-z-regression\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~\Documents\Anthropic\Profesional\Projects\Github\zPhoto\photo-z-regression\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
# ...

# %%
df[["u","g","r","i","z","u_g","g_r","r_i","i_z","redshift"]].corr()["redshift"].sort_values()
# Out:
# u_g        -0.068554
# i_z         0.002985
# r_i         0.151666
# g_r         0.200606
# z           0.269897
# i           0.287665
# r           0.328623
# g           0.428067
# u           0.432998
# redshift    1.000000
# Name: redshift, dtype: float64

# %%
df.sample(1000, random_state=42).to_csv("data/sample_small.csv", index=False)
print("saved")
# Out:
# saved
